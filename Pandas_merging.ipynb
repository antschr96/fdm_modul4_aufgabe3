# %% [markdown]
# # Zertifikatskurs Forschungsdatenmanagement
# ## Modul 4 -  Hacken & experimentieren mit Daten (14.11.2022 - 16.12.2022)
#
# ### Aufgabe 3, - Python, Teil 1
#
#
# **Aufgabenbeschreibung:**
#
# Merge zweier Datensätze mit unterschiedlichen Optionen der Funkion: pandas.DataFrame.merge
# Dokumentation der Funktion: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html

# %%
import pandas as pd

# %%
# define dataframes

# journal dataset
doi_df_journal = pd.DataFrame({
    "DOI": [
        "10.1371/journal.pcbi.1004668",
        "10.21105/joss.01035",
        "10.12688/f1000research.18866.2",
        "10.1038/s41598-019-52881-4",
        "10.1186/s12859-019-3171-0"],
    "journal": [
        "PLoS Comput Biol",
        "JOSS",
        "F1000Res",
        "Sci Rep",
        "BMC Bioinformatics"]})

# Author dataset
doi_df_first_author = pd.DataFrame({
    "DOI": [
        "10.1371/journal.pcbi.1004668",
        "10.21105/joss.01035",
        "10.21105/joss.01006",
        "10.12688/f1000research.18866.2",
        "10.1186/s12859-019-3171-0"],
    "first_author": [
        "Blischak",
        "Sparks",
        "Granger",
        "Thang",
        "Chen"]})

# %%
doi_df_first_author
# Out:
#                               DOI first_author
# 0    10.1371/journal.pcbi.1004668     Blischak
# 1             10.21105/joss.01035       Sparks
# 2             10.21105/joss.01006      Granger
# 3  10.12688/f1000research.18866.2        Thang
# 4       10.1186/s12859-019-3171-0         Chen

# %%
doi_df_journal
# Out:
#                               DOI             journal
# 0    10.1371/journal.pcbi.1004668    PLoS Comput Biol
# 1             10.21105/joss.01035                JOSS
# 2  10.12688/f1000research.18866.2            F1000Res
# 3      10.1038/s41598-019-52881-4             Sci Rep
# 4       10.1186/s12859-019-3171-0  BMC Bioinformatics

# %%
# Merge Dataframes - left merge
doi_df_first_author.merge(doi_df_journal, on="DOI", how="left")
# Zu jedem Autorendatensatz wird das Journal angezeigt, vorausgesetzt, die verbindende DOI ist in beiden Dataframes vorhanden, sonst wird NA angezeigt.
# Out:
#                               DOI first_author             journal
# 0    10.1371/journal.pcbi.1004668     Blischak    PLoS Comput Biol
# 1             10.21105/joss.01035       Sparks                JOSS
# 2             10.21105/joss.01006      Granger                 NaN
# 3  10.12688/f1000research.18866.2        Thang            F1000Res
# 4       10.1186/s12859-019-3171-0         Chen  BMC Bioinformatics

# %%
# Merge Dataframes - right merge
doi_df_first_author.merge(doi_df_journal, on="DOI", how="right")
# Enthält alle Datensätze aus dem Journal-Datensatz, ist kein Autoren-Datensatz vorhanden, wird NA für fehlende Werte eingetragen.
# Out:
#                               DOI first_author             journal
# 0    10.1371/journal.pcbi.1004668     Blischak    PLoS Comput Biol
# 1             10.21105/joss.01035       Sparks                JOSS
# 2  10.12688/f1000research.18866.2        Thang            F1000Res
# 3      10.1038/s41598-019-52881-4          NaN             Sci Rep
# 4       10.1186/s12859-019-3171-0         Chen  BMC Bioinformatics

# %%
# Merge Dataframes - inner merge
doi_df_first_author.merge(doi_df_journal, on="DOI", how="inner")
# Enthält nur die Datensätze, zu denen sowohl ein Autor als auch ein Journal-Datensatz vorhanden ist.
# Out:
#                               DOI first_author             journal
# 0    10.1371/journal.pcbi.1004668     Blischak    PLoS Comput Biol
# 1             10.21105/joss.01035       Sparks                JOSS
# 2  10.12688/f1000research.18866.2        Thang            F1000Res
# 3       10.1186/s12859-019-3171-0         Chen  BMC Bioinformatics

# %%
# Merge Dataframes - outer merge
doi_df_first_author.merge(doi_df_journal, on="DOI", how="outer")
# Enthält für jede DOI eine Zeile, jeweils fehlende Werte (Autor oder Journal) werden mit NaN ausgegeben.
# Out:
#                               DOI first_author             journal
# 0    10.1371/journal.pcbi.1004668     Blischak    PLoS Comput Biol
# 1             10.21105/joss.01035       Sparks                JOSS
# 2             10.21105/joss.01006      Granger                 NaN
# 3  10.12688/f1000research.18866.2        Thang            F1000Res
# 4       10.1186/s12859-019-3171-0         Chen  BMC Bioinformatics
# 5      10.1038/s41598-019-52881-4          NaN             Sci Rep

# %%
# Merge Dataframes - outer merge - changed order of data frames
doi_df_journal.merge(doi_df_first_author, on="DOI", how="outer")
# Enthält für jede DOI eine Zeile, jeweils fehlende Werte (Autor oder Journal) werden mit NaN ausgegeben.
# Out:
#                               DOI             journal first_author
# 0    10.1371/journal.pcbi.1004668    PLoS Comput Biol     Blischak
# 1             10.21105/joss.01035                JOSS       Sparks
# 2  10.12688/f1000research.18866.2            F1000Res        Thang
# 3      10.1038/s41598-019-52881-4             Sci Rep          NaN
# 4       10.1186/s12859-019-3171-0  BMC Bioinformatics         Chen
# 5             10.21105/joss.01006                 NaN      Granger

# %%
# Merge Dataframes - cross merge (not required)
doi_df_first_author.merge(doi_df_journal, how="cross")
# jetzt noch die Variante "cross merge" ausprobieren, obwohl die keinen Sinn für diese Daten macht: sie merged jeden Datensatz aus dem einen dataframe mit jedem Datensatz des Journal Dataframes.
# Out:
#                              DOI_x first_author  \
# 0     10.1371/journal.pcbi.1004668     Blischak
# 1     10.1371/journal.pcbi.1004668     Blischak
# 2     10.1371/journal.pcbi.1004668     Blischak
# 3     10.1371/journal.pcbi.1004668     Blischak
# 4     10.1371/journal.pcbi.1004668     Blischak
# 5              10.21105/joss.01035       Sparks
# 6              10.21105/joss.01035       Sparks
# 7              10.21105/joss.01035       Sparks
# 8              10.21105/joss.01035       Sparks
# 9              10.21105/joss.01035       Sparks
# 10             10.21105/joss.01006      Granger
# 11             10.21105/joss.01006      Granger
# 12             10.21105/joss.01006      Granger
# 13             10.21105/joss.01006      Granger
# 14             10.21105/joss.01006      Granger
# 15  10.12688/f1000research.18866.2        Thang
# 16  10.12688/f1000research.18866.2        Thang
# 17  10.12688/f1000research.18866.2        Thang
# ...
